# %%
import subprocess
import time
import threading
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torch.utils.data import random_split, WeightedRandomSampler, Subset
from collections import Counter
import torch.cuda.amp as amp
from torch import nn, optim
import copy
from torch.optim import lr_scheduler
import timm
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
import numpy as np

# %%
def get_gpu_usage():
    result = subprocess.run(['nvidia-smi', '--query-gpu=utilization.gpu', '--format=csv,noheader,nounits'], 
                            stdout=subprocess.PIPE)
    return int(result.stdout.decode('utf-8').strip())

class DynamicDataLoader:
    def __init__(self, dataset, batch_size=32, num_workers=4, pin_memory=True, prefetch_factor=2):
        self.dataset = dataset
        self.batch_size = batch_size
        self.num_workers = num_workers
        self.pin_memory = pin_memory
        self.prefetch_factor = prefetch_factor
        self.loader = self.create_loader()
        self.adjusting = False
        self.target_gpu_usage = 95  # Target GPU usage in percent

    def create_loader(self):
        return DataLoader(self.dataset, batch_size=self.batch_size, shuffle=True, num_workers=self.num_workers, 
                          pin_memory=self.pin_memory, prefetch_factor=self.prefetch_factor, persistent_workers=True)

    def adjust_num_workers(self):
        while self.adjusting:
            gpu_usage = get_gpu_usage()
            print(f"Current GPU usage: {gpu_usage}%")
            if gpu_usage < self.target_gpu_usage - 10 and self.num_workers < 16:
                self.num_workers += 1
                print(f"Increasing num_workers to {self.num_workers}")
            elif gpu_usage > self.target_gpu_usage + 10 and self.num_workers > 1:
                self.num_workers -= 1
                print(f"Decreasing num_workers to {self.num_workers}")
            self.loader = self.create_loader()
            time.sleep(20)

    def start_adjusting(self):
        self.adjusting = True
        self.adjust_thread = threading.Thread(target=self.adjust_num_workers)
        self.adjust_thread.start()

    def stop_adjusting(self):
        self.adjusting = False
        self.adjust_thread.join()

    def get_loader(self):
        return self.loader

# %%
base_dir = './image_data/'

# 데이터 전처리 및 증강
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(380),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),
        transforms.RandomVerticalFlip(),
        transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(400),
        transforms.CenterCrop(380),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# 전체 데이터셋 로드
full_dataset = datasets.ImageFolder(base_dir, transform=data_transforms['train'])

# 클래스별 이미지 개수 출력
class_counts = Counter([full_dataset.targets[i] for i in range(len(full_dataset))])
print("Original class distribution:", class_counts)

# WeightedRandomSampler 사용하여 클래스 불균형 해결
class_weights = [1.0 / class_counts[i] for i in range(len(class_counts))]
sample_weights = [class_weights[label] for label in full_dataset.targets]
sampler = WeightedRandomSampler(sample_weights, num_samples=len(sample_weights), replacement=True)

print("Splitting dataset into training and test sets...")
train_size = int(0.8 * len(full_dataset))
test_size = len(full_dataset) - train_size
train_dataset, test_dataset = random_split(full_dataset, [train_size, test_size])

# 훈련 데이터셋과 테스트 데이터셋 각각에 다른 변환 적용
train_dataset.dataset.transform = data_transforms['train']
test_dataset.dataset.transform = data_transforms['test']

# DynamicDataLoader 사용
dynamic_loader = DynamicDataLoader(train_dataset, batch_size=32, num_workers=4, pin_memory=True, prefetch_factor=4)
dynamic_loader.start_adjusting()

test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True, num_workers=4, pin_memory=True, prefetch_factor=4, persistent_workers=True)

dataloaders = {'train': dynamic_loader.get_loader(), 'test': test_loader}
dataset_sizes = {'train': len(train_dataset), 'test': len(test_dataset)}
class_names = full_dataset.classes

print("Training and test data are ready.")
# Out:
# Original class distribution: Counter({0: 126, 1: 126, 2: 126, 3: 126})
# Splitting dataset into training and test sets...
# Training and test data are ready.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def train_and_evaluate(params):
    model = timm.create_model('efficientnet_b4', pretrained=True)
    num_ftrs = model.classifier.in_features
    model.classifier = nn.Sequential(
        nn.Dropout(params['dropout']),
        nn.Linear(num_ftrs, len(class_names))
    )
    model = model.to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=params['lr'], weight_decay=params['weight_decay'])
    scaler = amp.GradScaler()
    scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.1, patience=10, threshold_mode='rel')

    num_epochs = 80
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_test_acc = 0.0  # 가장 높은 테스트 데이터 정확도를 저장하기 위한 변수

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        for phase in ['train', 'test']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    with amp.autocast():
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                    if phase == 'train':
                        scaler.scale(loss).backward()
                        scaler.step(optimizer)
                        scaler.update()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            if phase == 'test':
                scheduler.step(epoch_acc)

                if epoch_acc > best_acc:
                    best_acc = epoch_acc
                    best_model_wts = copy.deepcopy(model.state_dict())
                
                if epoch_acc > best_test_acc:
                    best_test_acc = epoch_acc

    model.load_state_dict(best_model_wts)
    return {'loss': -best_acc, 'status': STATUS_OK, 'model_state_dict': best_model_wts}

# Hyperopt를 위한 하이퍼파라미터 공간 정의
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64]),
    'lr': hp.loguniform('lr', np.log(0.00001), np.log(0.001)),
    'weight_decay': hp.loguniform('weight_decay', np.log(0.0001), np.log(0.01)),
    'dropout': hp.uniform('dropout', 0.2, 0.7)
}

# 최적화 실행
trials = Trials()
best = fmin(fn=train_and_evaluate,
            space=space,
            algo=tpe.suggest,
            max_evals=20,
            trials=trials)

print(f"Best parameters: {best}")

# Save the best model
best_model = timm.create_model('efficientnet_b4', pretrained=True)
num_ftrs = best_model.classifier.in_features
best_model.classifier = nn.Sequential(
    nn.Dropout(best['dropout']),
    nn.Linear(num_ftrs, len(class_names))
)
best_model.load_state_dict(trials.best_trial['result']['model_state_dict'])
torch.save(best_model.state_dict(), 'personal_color_efficientnet_b4.pth')

# Print the best test accuracy
best_test_acc = trials.best_trial['result']['best_test_acc']
print(f"Best Test Accuracy: {best_test_acc:.4f}")

print("Training complete")
# Out:
# Current GPU usage: 4%
# Increasing num_workers to 5
# Epoch 0/79
# ----------
# train Loss: 1.3777 Acc: 0.3027
# test Loss: 1.3703 Acc: 0.3366
# Epoch 1/79
# ----------
# train Loss: 1.1158 Acc: 0.7767
# test Loss: 1.2214 Acc: 0.4851
# Epoch 2/79
# ----------
# train Loss: 0.5387 Acc: 0.8685
# test Loss: 0.9347 Acc: 0.6337
# Epoch 3/79
# ----------
# train Loss: 0.0717 Acc: 0.9901
# test Loss: 1.5579 Acc: 0.6238
# Epoch 4/79
# ----------
# train Loss: 0.0294 Acc: 0.9926
# test Loss: 1.6810 Acc: 0.6436
# Epoch 5/79
# ----------
# train Loss: 0.0060 Acc: 1.0000
# test Loss: 1.7747 Acc: 0.6436
# Epoch 6/79
# ----------
# Current GPU usage: 93%
# train Loss: 0.0120 Acc: 0.9926
# test Loss: 1.9444 Acc: 0.6733
# Epoch 7/79
# ----------
# train Loss: 0.0674 Acc: 0.9851
# test Loss: 2.1898 Acc: 0.5446
# Epoch 8/79
# ----------
# train Loss: 0.0734 Acc: 0.9702
# test Loss: 2.2593 Acc: 0.6238
# Epoch 9/79
# ----------
# train Loss: 0.0364 Acc: 0.9876
# test Loss: 1.9384 Acc: 0.6040
# Epoch 10/79
# ----------
# train Loss: 0.0305 Acc: 0.9876
# test Loss: 1.6161 Acc: 0.6436
# Epoch 11/79
# ----------
# train Loss: 0.0301 Acc: 0.9876
# test Loss: 1.5061 Acc: 0.6535
# Epoch 12/79
# ----------
# train Loss: 0.0273 Acc: 0.9901
# test Loss: 1.4895 Acc: 0.6535
# Epoch 13/79
# ----------
# train Loss: 0.0161 Acc: 0.9950
# test Loss: 1.6451 Acc: 0.6832
# Epoch 14/79
# ----------
# train Loss: 0.0128 Acc: 0.9975
# test Loss: 2.0969 Acc: 0.6832
# Epoch 15/79
# ----------
# Current GPU usage: 88%
# train Loss: 0.0062 Acc: 0.9975
# test Loss: 1.9975 Acc: 0.7129
# Epoch 16/79
# ----------
# train Loss: 0.0113 Acc: 0.9975
# test Loss: 1.8745 Acc: 0.6535
# Epoch 17/79
# ----------
# train Loss: 0.0006 Acc: 1.0000
# test Loss: 1.8960 Acc: 0.6931
# Epoch 18/79
# ----------
# train Loss: 0.0226 Acc: 0.9950
# test Loss: 2.2614 Acc: 0.6436
# Epoch 19/79
# ----------
# train Loss: 0.0199 Acc: 0.9926
# test Loss: 1.7605 Acc: 0.6436
# Epoch 20/79
# ----------
# train Loss: 0.0112 Acc: 0.9950
# test Loss: 1.7756 Acc: 0.6634
# Epoch 21/79
# ----------
# train Loss: 0.0252 Acc: 0.9901
# test Loss: 1.9027 Acc: 0.6634
# Epoch 22/79
# ----------
# train Loss: 0.0178 Acc: 0.9901
# test Loss: 2.4236 Acc: 0.6040
# Epoch 23/79
# ----------
# train Loss: 0.0140 Acc: 0.9950
# test Loss: 2.4651 Acc: 0.6139
# Epoch 24/79
# ----------
# Current GPU usage: 95%
# train Loss: 0.0151 Acc: 0.9926
# test Loss: 2.1158 Acc: 0.6238
# Epoch 25/79
# ----------
# train Loss: 0.0144 Acc: 0.9950
# test Loss: 2.1969 Acc: 0.6436
# Epoch 26/79
# ----------
# train Loss: 0.0259 Acc: 0.9901
# test Loss: 2.2054 Acc: 0.6535
# Epoch 27/79
# ----------
# train Loss: 0.0052 Acc: 1.0000
# test Loss: 1.9995 Acc: 0.6832
# Epoch 28/79
# ----------
# train Loss: 0.0063 Acc: 1.0000
# test Loss: 2.0660 Acc: 0.6634
# Epoch 29/79
# ----------
# train Loss: 0.0060 Acc: 0.9975
# test Loss: 2.0573 Acc: 0.6535
# Epoch 30/79
# ----------
# train Loss: 0.0119 Acc: 0.9975
# test Loss: 1.9423 Acc: 0.6733
# Epoch 31/79
# ----------
# train Loss: 0.0012 Acc: 1.0000
# test Loss: 1.8810 Acc: 0.6634
# Epoch 32/79
# ----------
# train Loss: 0.0033 Acc: 1.0000
# test Loss: 1.8257 Acc: 0.6733
# Epoch 33/79
# ----------
# Current GPU usage: 95%
# train Loss: 0.0012 Acc: 1.0000
# test Loss: 1.8566 Acc: 0.6634
# Epoch 34/79
# ----------
# train Loss: 0.0051 Acc: 1.0000
# test Loss: 1.9376 Acc: 0.6436
# Epoch 35/79
# ----------
# train Loss: 0.0026 Acc: 1.0000
# test Loss: 1.9652 Acc: 0.6535
# Epoch 36/79
# ----------
# train Loss: 0.0014 Acc: 1.0000
# test Loss: 1.9695 Acc: 0.6535
# Epoch 37/79
# ----------
# train Loss: 0.0012 Acc: 1.0000
# test Loss: 1.9416 Acc: 0.6634
# Epoch 38/79
# ----------
# train Loss: 0.0011 Acc: 1.0000
# test Loss: 1.9927 Acc: 0.6535
# Epoch 39/79
# ----------
# train Loss: 0.0009 Acc: 1.0000
# test Loss: 1.8821 Acc: 0.6634
# Epoch 40/79
# ----------
# train Loss: 0.0030 Acc: 0.9975
# test Loss: 1.8684 Acc: 0.6634
# Epoch 41/79
# ----------
# train Loss: 0.0009 Acc: 1.0000
# test Loss: 1.9026 Acc: 0.6634
# Epoch 42/79
# ----------
# Current GPU usage: 43%
# Increasing num_workers to 6
# train Loss: 0.0004 Acc: 1.0000
# test Loss: 1.9312 Acc: 0.6535
# Epoch 43/79
# ----------
# train Loss: 0.0006 Acc: 1.0000
# test Loss: 1.9440 Acc: 0.6436
# Epoch 44/79
# ----------
# train Loss: 0.0013 Acc: 1.0000
# test Loss: 1.9138 Acc: 0.6535
# Epoch 45/79
# ----------
# train Loss: 0.0010 Acc: 1.0000
# test Loss: 1.8777 Acc: 0.6535
# Epoch 46/79
# ----------
# train Loss: 0.0004 Acc: 1.0000
# test Loss: 1.9517 Acc: 0.6535
# Epoch 47/79
# ----------
# train Loss: 0.0008 Acc: 1.0000
# test Loss: 1.9723 Acc: 0.6634
# Epoch 48/79
# ----------
# train Loss: 0.0013 Acc: 1.0000
# test Loss: 1.9761 Acc: 0.6535
# Epoch 49/79
# ----------
# train Loss: 0.0009 Acc: 1.0000
# test Loss: 1.9999 Acc: 0.6535
# Epoch 50/79
# ----------
# train Loss: 0.0004 Acc: 1.0000
# test Loss: 1.9413 Acc: 0.6535
# Epoch 51/79
# ----------
# Current GPU usage: 68%
# Increasing num_workers to 7
# train Loss: 0.0007 Acc: 1.0000
# test Loss: 1.8654 Acc: 0.6634
# Epoch 52/79
# ----------
# train Loss: 0.0008 Acc: 1.0000
# test Loss: 1.9041 Acc: 0.6535
# Epoch 53/79
# ----------
# train Loss: 0.0032 Acc: 1.0000
# test Loss: 1.9764 Acc: 0.6436
# Epoch 54/79
# ----------
# train Loss: 0.0050 Acc: 1.0000
# test Loss: 1.9203 Acc: 0.6634
# Epoch 55/79
# ----------
# train Loss: 0.0004 Acc: 1.0000
# test Loss: 1.9847 Acc: 0.6436
# Epoch 56/79
# ----------
# train Loss: 0.0004 Acc: 1.0000
# test Loss: 1.9498 Acc: 0.6535
# Epoch 57/79
# ----------
# train Loss: 0.0004 Acc: 1.0000
# test Loss: 1.9298 Acc: 0.6535
# Epoch 58/79
# ----------
# train Loss: 0.0005 Acc: 1.0000
# test Loss: 1.8863 Acc: 0.6535
# Epoch 59/79
# ----------
# train Loss: 0.0012 Acc: 1.0000
# Current GPU usage: 41%
# Increasing num_workers to 8
# test Loss: 1.9600 Acc: 0.6535
# Epoch 60/79
# ----------
# train Loss: 0.0039 Acc: 0.9975
# test Loss: 1.8637 Acc: 0.6733
# Epoch 61/79
# ----------
# train Loss: 0.0072 Acc: 0.9975
# test Loss: 1.9718 Acc: 0.6634
# Epoch 62/79
# ----------
# train Loss: 0.0005 Acc: 1.0000
# test Loss: 1.9206 Acc: 0.6634
# Epoch 63/79
# ----------
# train Loss: 0.0020 Acc: 1.0000
# test Loss: 1.9501 Acc: 0.6535
# Epoch 64/79
# ----------
# train Loss: 0.0059 Acc: 0.9950
# test Loss: 1.9500 Acc: 0.6535
# Epoch 65/79
# ----------
# train Loss: 0.0005 Acc: 1.0000
# test Loss: 1.9584 Acc: 0.6436
# Epoch 66/79
# ----------
# train Loss: 0.0008 Acc: 1.0000
# test Loss: 1.9643 Acc: 0.6634
# Epoch 67/79
# ----------
# train Loss: 0.0013 Acc: 1.0000
# test Loss: 1.9136 Acc: 0.6634
# Epoch 68/79
# ----------
# train Loss: 0.0005 Acc: 1.0000
# Current GPU usage: 85%
# test Loss: 1.9134 Acc: 0.6733
# Epoch 69/79
# ----------
# train Loss: 0.0012 Acc: 1.0000
# test Loss: 1.9009 Acc: 0.6634
# Epoch 70/79
# ----------
# train Loss: 0.0031 Acc: 0.9975
# test Loss: 2.0551 Acc: 0.6436
# Epoch 71/79
# ----------
# train Loss: 0.0006 Acc: 1.0000
# test Loss: 2.0148 Acc: 0.6337
# Epoch 72/79
# ----------
# train Loss: 0.0005 Acc: 1.0000
# test Loss: 1.9811 Acc: 0.6535
# Epoch 73/79
# ----------
# train Loss: 0.0015 Acc: 1.0000
# test Loss: 1.9694 Acc: 0.6535
# Epoch 74/79
# ----------
# train Loss: 0.0010 Acc: 1.0000
# test Loss: 1.9642 Acc: 0.6535
# Epoch 75/79
# ----------
# train Loss: 0.0004 Acc: 1.0000
# test Loss: 1.9152 Acc: 0.6634
# Epoch 76/79
# ----------
# train Loss: 0.0018 Acc: 1.0000
# test Loss: 1.9577 Acc: 0.6634
# Epoch 77/79
# ----------
# train Loss: 0.0013 Acc: 1.0000
# Current GPU usage: 73%
# Increasing num_workers to 9
# test Loss: 1.9388 Acc: 0.6535
# Epoch 78/79
# ----------
# train Loss: 0.0003 Acc: 1.0000
# test Loss: 1.9419 Acc: 0.6535
# Epoch 79/79
# ----------
# train Loss: 0.0014 Acc: 1.0000
# test Loss: 1.9185 Acc: 0.6535
# Epoch 0/79
# ----------
# train Loss: 1.3868 Acc: 0.2928
# test Loss: 1.3787 Acc: 0.2772
# Epoch 1/79
# ----------
# train Loss: 1.3409 Acc: 0.5161
# test Loss: 1.3602 Acc: 0.4851
# Epoch 2/79
# ----------
# train Loss: 1.2865 Acc: 0.6799
# test Loss: 1.3403 Acc: 0.4059
# Epoch 3/79
# ----------
# train Loss: 1.2148 Acc: 0.6973
# test Loss: 1.3096 Acc: 0.3960
# Epoch 4/79
# ----------
# train Loss: 1.0831 Acc: 0.6824
# test Loss: 1.2361 Acc: 0.4455
# Epoch 5/79
# ----------
# train Loss: 0.8368 Acc: 0.8015
# test Loss: 1.1049 Acc: 0.5743
# Epoch 6/79
# ----------
# Current GPU usage: 91%
# train Loss: 0.5053 Acc: 0.8784
# test Loss: 0.9902 Acc: 0.5644
# Epoch 7/79
# ----------
# train Loss: 0.2355 Acc: 0.9529
# test Loss: 0.8537 Acc: 0.6238
# Epoch 8/79
# ----------
# train Loss: 0.1138 Acc: 0.9752
# test Loss: 0.9082 Acc: 0.6634
# Epoch 9/79
# ----------
# train Loss: 0.0437 Acc: 0.9950
# test Loss: 0.9632 Acc: 0.6535
# Epoch 10/79
# ----------
# train Loss: 0.0211 Acc: 1.0000
# test Loss: 1.0549 Acc: 0.6436
# Epoch 11/79
# ----------
# train Loss: 0.0110 Acc: 1.0000
# test Loss: 1.1079 Acc: 0.6535
# Epoch 12/79
# ----------
# train Loss: 0.0187 Acc: 0.9975
# test Loss: 1.1607 Acc: 0.6634
# Epoch 13/79
# ----------
# train Loss: 0.0078 Acc: 1.0000
# test Loss: 1.2405 Acc: 0.6436
# Epoch 14/79
# ----------
# train Loss: 0.0246 Acc: 0.9901
# test Loss: 1.1415 Acc: 0.6436
# Epoch 15/79
# ----------
# Current GPU usage: 95%
# train Loss: 0.0091 Acc: 1.0000
# test Loss: 1.3195 Acc: 0.6436
# Epoch 16/79
# ----------
# train Loss: 0.0061 Acc: 1.0000
# test Loss: 1.2264 Acc: 0.6436
# Epoch 17/79
# ----------
# train Loss: 0.0042 Acc: 1.0000
# test Loss: 1.2301 Acc: 0.6634
# Epoch 18/79
# ----------
# train Loss: 0.0053 Acc: 1.0000
# test Loss: 1.2096 Acc: 0.6535
# Epoch 19/79
# ----------
# train Loss: 0.0049 Acc: 1.0000
# test Loss: 1.2429 Acc: 0.6535
# Epoch 20/79
# ----------
# train Loss: 0.0036 Acc: 1.0000
# test Loss: 1.2515 Acc: 0.6535
# Epoch 21/79
# ----------
# train Loss: 0.0033 Acc: 1.0000
# test Loss: 1.2644 Acc: 0.6634
# Epoch 22/79
# ----------
# train Loss: 0.0026 Acc: 1.0000
# test Loss: 1.2370 Acc: 0.6832
# Epoch 23/79
# ----------
# train Loss: 0.0025 Acc: 1.0000
# test Loss: 1.2391 Acc: 0.6634
# Epoch 24/79
# ----------
# Current GPU usage: 95%
# train Loss: 0.0046 Acc: 1.0000
# test Loss: 1.2397 Acc: 0.6535
# Epoch 25/79
# ----------
# train Loss: 0.0040 Acc: 1.0000
# test Loss: 1.2459 Acc: 0.6634
# Epoch 26/79
# ----------
# train Loss: 0.0030 Acc: 1.0000
# test Loss: 1.2529 Acc: 0.6733
# Epoch 27/79
# ----------
# train Loss: 0.0030 Acc: 1.0000
# test Loss: 1.2575 Acc: 0.6832
# Epoch 28/79
# ----------
# train Loss: 0.0025 Acc: 1.0000
# test Loss: 1.2717 Acc: 0.6733
# Epoch 29/79
# ----------
# train Loss: 0.0017 Acc: 1.0000
# test Loss: 1.2820 Acc: 0.6634
# Epoch 30/79
# ----------
# train Loss: 0.0022 Acc: 1.0000
# test Loss: 1.2583 Acc: 0.6634
# Epoch 31/79
# ----------
# train Loss: 0.0032 Acc: 1.0000
# test Loss: 1.2710 Acc: 0.6733
# Epoch 32/79
# ----------
# train Loss: 0.0018 Acc: 1.0000
# test Loss: 1.2645 Acc: 0.6832
# Epoch 33/79
# ----------
# Current GPU usage: 92%
# train Loss: 0.0083 Acc: 0.9975
# test Loss: 1.2788 Acc: 0.6733
# Epoch 34/79
# ----------
# train Loss: 0.0022 Acc: 1.0000
# test Loss: 1.2862 Acc: 0.6634
# Epoch 35/79
# ----------
# train Loss: 0.0023 Acc: 1.0000
# test Loss: 1.2849 Acc: 0.6832
# Epoch 36/79
# ----------
# train Loss: 0.0023 Acc: 1.0000
# test Loss: 1.2729 Acc: 0.6634
# Epoch 37/79
# ----------
# train Loss: 0.0020 Acc: 1.0000
# test Loss: 1.2878 Acc: 0.6733
# Epoch 38/79
# ----------
# train Loss: 0.0022 Acc: 1.0000
# test Loss: 1.2832 Acc: 0.6832
# Epoch 39/79
# ----------
# train Loss: 0.0016 Acc: 1.0000
# test Loss: 1.2598 Acc: 0.6733
# Epoch 40/79
# ----------
# train Loss: 0.0019 Acc: 1.0000
# test Loss: 1.2450 Acc: 0.6832
# Epoch 41/79
# ----------
# train Loss: 0.0022 Acc: 1.0000
# test Loss: 1.2557 Acc: 0.6733
# Epoch 42/79
# ----------
# Current GPU usage: 92%
# train Loss: 0.0081 Acc: 0.9975
# test Loss: 1.2378 Acc: 0.6733
# Epoch 43/79
# ----------
# train Loss: 0.0034 Acc: 1.0000
# test Loss: 1.2867 Acc: 0.6832
# Epoch 44/79
# ----------
# train Loss: 0.0029 Acc: 1.0000
# test Loss: 1.2724 Acc: 0.6634
# Epoch 45/79
# ----------
# train Loss: 0.0048 Acc: 0.9975
# test Loss: 1.2510 Acc: 0.6733
# Epoch 46/79
# ----------
# train Loss: 0.0011 Acc: 1.0000
# test Loss: 1.2845 Acc: 0.6832
# Epoch 47/79
# ----------
# train Loss: 0.0024 Acc: 1.0000
# test Loss: 1.2651 Acc: 0.6634
# Epoch 48/79
# ----------
# train Loss: 0.0025 Acc: 1.0000
# test Loss: 1.2338 Acc: 0.6535
# Epoch 49/79
# ----------
# train Loss: 0.0028 Acc: 1.0000
# test Loss: 1.2707 Acc: 0.6733
# Epoch 50/79
# ----------
# train Loss: 0.0028 Acc: 1.0000
# test Loss: 1.2756 Acc: 0.6634
# Epoch 51/79
# ----------
# Current GPU usage: 94%
# train Loss: 0.0020 Acc: 1.0000
# test Loss: 1.2878 Acc: 0.6832
# Epoch 52/79
# ----------
# train Loss: 0.0065 Acc: 1.0000
# test Loss: 1.2764 Acc: 0.6733
# Epoch 53/79
# ----------
# train Loss: 0.0057 Acc: 0.9975
# test Loss: 1.3152 Acc: 0.6733
# Epoch 54/79
# ----------
# train Loss: 0.0032 Acc: 1.0000
# test Loss: 1.2831 Acc: 0.6733
# Epoch 55/79
# ----------
# train Loss: 0.0016 Acc: 1.0000
# test Loss: 1.3124 Acc: 0.6832
# Epoch 56/79
# ----------
# train Loss: 0.0090 Acc: 0.9975
# test Loss: 1.2793 Acc: 0.6733
# Epoch 57/79
# ----------
# train Loss: 0.0028 Acc: 1.0000
# test Loss: 1.2665 Acc: 0.6733
# Epoch 58/79
# ----------
# train Loss: 0.0026 Acc: 1.0000
# test Loss: 1.2939 Acc: 0.6832
# Epoch 59/79
# ----------
# train Loss: 0.0028 Acc: 1.0000
# test Loss: 1.2524 Acc: 0.6634
# Epoch 60/79
# ----------
# Current GPU usage: 94%
# train Loss: 0.0025 Acc: 1.0000
# test Loss: 1.2444 Acc: 0.6733
# Epoch 61/79
# ----------
# train Loss: 0.0025 Acc: 1.0000
# test Loss: 1.2631 Acc: 0.6634
# Epoch 62/79
# ----------
# train Loss: 0.0023 Acc: 1.0000
# test Loss: 1.2862 Acc: 0.6634
# Epoch 63/79
# ----------
# train Loss: 0.0045 Acc: 1.0000
# test Loss: 1.3035 Acc: 0.6931
# Epoch 64/79
# ----------
# train Loss: 0.0031 Acc: 1.0000
# test Loss: 1.2945 Acc: 0.6634
# Epoch 65/79
# ----------
# train Loss: 0.0022 Acc: 1.0000
# test Loss: 1.2702 Acc: 0.6733
# Epoch 66/79
# ----------
# train Loss: 0.0042 Acc: 1.0000
# test Loss: 1.2859 Acc: 0.6832
# Epoch 67/79
# ----------
# train Loss: 0.0025 Acc: 1.0000
# test Loss: 1.2811 Acc: 0.6634
# Epoch 68/79
# ----------
# train Loss: 0.0035 Acc: 1.0000
# test Loss: 1.2731 Acc: 0.6634
# Epoch 69/79
# ----------
# Current GPU usage: 92%
# train Loss: 0.0020 Acc: 1.0000
# test Loss: 1.2823 Acc: 0.6832
# Epoch 70/79
# ----------
# train Loss: 0.0010 Acc: 1.0000
# test Loss: 1.2716 Acc: 0.6832
# Epoch 71/79
# ----------
# train Loss: 0.0024 Acc: 1.0000
# test Loss: 1.2733 Acc: 0.6832
# Epoch 72/79
# ----------
# train Loss: 0.0032 Acc: 1.0000
# test Loss: 1.2807 Acc: 0.6733
# Epoch 73/79
# ----------
# train Loss: 0.0022 Acc: 1.0000
# test Loss: 1.2960 Acc: 0.6733
# Epoch 74/79
# ----------
# train Loss: 0.0044 Acc: 1.0000
# test Loss: 1.2678 Acc: 0.6634
# Epoch 75/79
# ----------
# train Loss: 0.0027 Acc: 1.0000
# test Loss: 1.2554 Acc: 0.6634
# Epoch 76/79
# ----------
# train Loss: 0.0029 Acc: 1.0000
# test Loss: 1.2444 Acc: 0.6634
# Epoch 77/79
# ----------
# train Loss: 0.0017 Acc: 1.0000
# test Loss: 1.2652 Acc: 0.6535
# Epoch 78/79
# ----------
# Current GPU usage: 94%
# train Loss: 0.0036 Acc: 1.0000
# test Loss: 1.2764 Acc: 0.6535
# Epoch 79/79
# ----------
# train Loss: 0.0017 Acc: 1.0000
# test Loss: 1.2740 Acc: 0.6733
# Epoch 0/79
# ----------
# train Loss: 1.3817 Acc: 0.2978
# test Loss: 1.3815 Acc: 0.3465
# Epoch 1/79
# ----------
# train Loss: 1.3237 Acc: 0.5881
# test Loss: 1.3558 Acc: 0.5050
# Epoch 2/79
# ----------
# train Loss: 1.2486 Acc: 0.7618
# test Loss: 1.3226 Acc: 0.5248
# Epoch 3/79
# ----------
# train Loss: 1.1290 Acc: 0.7568
# test Loss: 1.2622 Acc: 0.5050
# Epoch 4/79
# ----------
# train Loss: 0.8797 Acc: 0.8536
# test Loss: 1.1321 Acc: 0.5842
# Epoch 5/79
# ----------
# train Loss: 0.5221 Acc: 0.9132
# test Loss: 1.0491 Acc: 0.5842
# Epoch 6/79
# ----------
# train Loss: 0.2502 Acc: 0.9578
# ...
# ----------
# Current GPU usage: 96%
# train Loss: 0.0062 Acc: 1.0000
# test Loss: 1.1252 Acc: 0.6436
# Epoch 38/79
# ----------
# train Loss: 0.0029 Acc: 1.0000
# test Loss: 1.1416 Acc: 0.6535
# Epoch 39/79
# ----------
# train Loss: 0.0025 Acc: 1.0000
# test Loss: 1.1208 Acc: 0.6535
# Epoch 40/79
# ----------
# train Loss: 0.0032 Acc: 1.0000
# test Loss: 1.1213 Acc: 0.6634
# Epoch 41/79
# ----------
# train Loss: 0.0054 Acc: 1.0000
# test Loss: 1.1202 Acc: 0.6634
# Epoch 42/79
# ----------
# train Loss: 0.0072 Acc: 1.0000
# test Loss: 1.1330 Acc: 0.6535
# Epoch 43/79
# ----------
# train Loss: 0.0027 Acc: 1.0000
# test Loss: 1.1270 Acc: 0.6733
# Epoch 44/79
# ----------
# train Loss: 0.0034 Acc: 1.0000
# test Loss: 1.1240 Acc: 0.6733
# Epoch 45/79
# ----------
# train Loss: 0.0051 Acc: 1.0000
# test Loss: 1.1464 Acc: 0.6634
# Epoch 46/79
# ----------
# train Loss: 0.0061 Acc: 0.9975
# test Loss: 1.1221 Acc: 0.6634
# Epoch 47/79
# ----------
# Current GPU usage: 65%
# train Loss: 0.0043 Acc: 1.0000
# test Loss: 1.1367 Acc: 0.6535
# Epoch 48/79
# ----------
# train Loss: 0.0036 Acc: 1.0000
# test Loss: 1.1352 Acc: 0.6634
# Epoch 49/79
# ----------
# train Loss: 0.0042 Acc: 1.0000
# test Loss: 1.1330 Acc: 0.6634
# Epoch 50/79
# ----------
# train Loss: 0.0031 Acc: 1.0000
# test Loss: 1.1112 Acc: 0.6634
# Epoch 51/79
# ----------
# train Loss: 0.0029 Acc: 1.0000
# test Loss: 1.1352 Acc: 0.6535
# Epoch 52/79
# ----------
# train Loss: 0.0103 Acc: 0.9975
# test Loss: 1.1336 Acc: 0.6634
# Epoch 53/79
# ----------
# train Loss: 0.0030 Acc: 1.0000
# test Loss: 1.1353 Acc: 0.6535
# Epoch 54/79
# ----------
# train Loss: 0.0030 Acc: 1.0000
# test Loss: 1.1473 Acc: 0.6535
# Epoch 55/79
# ----------
# train Loss: 0.0049 Acc: 1.0000
# test Loss: 1.1421 Acc: 0.6634
# Epoch 56/79
# ----------
# Current GPU usage: 96%
# train Loss: 0.0038 Acc: 1.0000
# test Loss: 1.1497 Acc: 0.6535
# Epoch 57/79
# ----------
# train Loss: 0.0050 Acc: 1.0000
# test Loss: 1.1393 Acc: 0.6436
# Epoch 58/79
# ----------
# train Loss: 0.0037 Acc: 1.0000
# test Loss: 1.1603 Acc: 0.6337
# Epoch 59/79
# ----------
# train Loss: 0.0033 Acc: 1.0000
# test Loss: 1.1473 Acc: 0.6436
# Epoch 60/79
# ----------
# train Loss: 0.0053 Acc: 1.0000
# test Loss: 1.1493 Acc: 0.6535
# Epoch 61/79
# ----------
# train Loss: 0.0028 Acc: 1.0000
# test Loss: 1.1612 Acc: 0.6337
# Epoch 62/79
# ----------
# train Loss: 0.0036 Acc: 1.0000
# test Loss: 1.1406 Acc: 0.6535
# Epoch 63/79
# ----------
# train Loss: 0.0024 Acc: 1.0000
# test Loss: 1.1234 Acc: 0.6634
# Epoch 64/79
# ----------
# train Loss: 0.0020 Acc: 1.0000
# test Loss: 1.1537 Acc: 0.6634
# Epoch 65/79
# ----------
# train Loss: 0.0056 Acc: 1.0000
# Current GPU usage: 96%
# test Loss: 1.1911 Acc: 0.6337
# Epoch 66/79
# ----------
# train Loss: 0.0029 Acc: 1.0000
# test Loss: 1.1613 Acc: 0.6535
# Epoch 67/79
# ----------
# train Loss: 0.0039 Acc: 1.0000
# test Loss: 1.1769 Acc: 0.6337
# Epoch 68/79
# ----------
# train Loss: 0.0054 Acc: 0.9975
# test Loss: 1.1650 Acc: 0.6436
# Epoch 69/79
# ----------
# train Loss: 0.0042 Acc: 1.0000
# test Loss: 1.1399 Acc: 0.6535
# Epoch 70/79
# ----------
# train Loss: 0.0040 Acc: 1.0000
# test Loss: 1.1287 Acc: 0.6634
# Epoch 71/79
# ----------
# train Loss: 0.0038 Acc: 1.0000
# test Loss: 1.1705 Acc: 0.6337
# Epoch 72/79
# ----------
# train Loss: 0.0027 Acc: 1.0000
# test Loss: 1.1546 Acc: 0.6634
# Epoch 73/79
# ----------
# train Loss: 0.0027 Acc: 1.0000
# test Loss: 1.1593 Acc: 0.6436
# Epoch 74/79
# ----------
# train Loss: 0.0025 Acc: 1.0000
# test Loss: 1.1612 Acc: 0.6535
# Epoch 75/79
# ----------
# Current GPU usage: 95%
# train Loss: 0.0028 Acc: 1.0000
# test Loss: 1.1492 Acc: 0.6436
# Epoch 76/79
# ----------
# train Loss: 0.0039 Acc: 1.0000
# test Loss: 1.1699 Acc: 0.6535
# Epoch 77/79
# ----------
# train Loss: 0.0028 Acc: 1.0000
# test Loss: 1.1805 Acc: 0.6238
# Epoch 78/79
# ----------
# train Loss: 0.0028 Acc: 1.0000
# test Loss: 1.1634 Acc: 0.6436
# Epoch 79/79
# ----------
# train Loss: 0.0033 Acc: 1.0000
# test Loss: 1.1593 Acc: 0.6436
# 100%|██████████| 20/20 [59:57<00:00, 179.86s/trial, best loss: -0.7623762376237624]
# Best parameters: {'batch_size': 2, 'dropout': 0.25020723272413975, 'lr': 0.00015019670724110767, 'weight_decay': 0.0011032218250943853}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 100
#      97 torch.save(best_model.state_dict(), 'personal_color_efficientnet_b4.pth')
#      99 # Print the best test accuracy
# --> 100 best_test_acc = trials.best_trial['result']['best_test_acc']
#     101 print(f"Best Test Accuracy: {best_test_acc:.4f}")
#     103 print("Training complete")
#
# KeyError: 'best_test_acc'
# Current GPU usage: 1%
# Current GPU usage: 0%
# Current GPU usage: 0%
# Current GPU usage: 1%
# Current GPU usage: 1%
# Current GPU usage: 0%
# Current GPU usage: 0%
# Current GPU usage: 0%
# Current GPU usage: 0%
# Current GPU usage: 0%
# Current GPU usage: 0%
# Current GPU usage: 0%
# Current GPU usage: 0%
# Current GPU usage: 0%
# Current GPU usage: 0%
# Current GPU usage: 0%
# Current GPU usage: 0%
# Current GPU usage: 0%
# Current GPU usage: 0%
# Current GPU usage: 2%
# Current GPU usage: 0%
# Current GPU usage: 0%

# %%
dynamic_loader.stop_adjusting()
